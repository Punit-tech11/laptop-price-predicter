# %%
import pandas as pd
import numpy as np
import sklearn as sns

# %%
df = pd.read_csv("laptopPrice.csv")

# %%
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(21)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 802 entries, 0 to 822
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand              802 non-null    object
#  1   processor_brand    802 non-null    object
#  2   processor_name     802 non-null    object
#  3   processor_gnrtn    802 non-null    object
#  4   ram_gb             802 non-null    object
#  5   ram_type           802 non-null    object
#  6   ssd                802 non-null    object
#  7   hdd                802 non-null    object
#  8   os                 802 non-null    object
#  9   os_bit             802 non-null    object
#  10  graphic_card_gb    802 non-null    object
#  11  weight             802 non-null    object
#  12  warranty           802 non-null    object
#  13  Touchscreen        802 non-null    object
#  14  msoffice           802 non-null    object
#  15  Price              802 non-null    int64
# ...

# %%
df['brand'].unique()
# Out:
# array(['ASUS', 'Lenovo', 'acer', 'Avita', 'HP', 'DELL', 'MSI', 'APPLE'],
#       dtype=object)

# %%
df['processor_brand'].unique()
# Out:
# array(['Intel', 'AMD', 'M1'], dtype=object)

# %%
processor_brand ={
    'Intel':1, 'AMD':2, 'M1':3
}

# %%
df['processor_brand']=df['processor_brand'].map(processor_brand)

# %%
df['processor_name'].unique()
# Out:
# array(['Core i3', 'Core i5', 'Celeron Dual', 'Ryzen 5', 'Core i7',
#        'Core i9', 'M1', 'Pentium Quad', 'Ryzen 3', 'Ryzen 7', 'Ryzen 9'],
#       dtype=object)

# %%
processor_name ={
     'Core i3':1,      'Core i5':2, 'Celeron Dual':3,      'Ryzen 5':4,
      'Core i7':5,      'Core i9':6,           'M1':7, 'Pentium Quad':8,
      'Ryzen 3':9,      'Ryzen 7':10,      'Ryzen 9':11
}

# %%
df['processor_name']=df['processor_name'].map(processor_name)

# %%
df['processor_gnrtn'].unique()
# Out:
# array(['10th', 'Not Available', '11th', '7th', '8th', '9th', '4th',
#        '12th'], dtype=object)

# %%
processor_gnrtn ={
    '10th':10, 'Not Available':0, '11th':11, '7th':7, '8th':8, '9th':9, '4th':4, '12th':12
}

# %%
df['processor_gnrtn']=df['processor_gnrtn'].map(processor_gnrtn)

# %%
df['ram_gb'].unique()
# Out:
# array(['4 GB', '8 GB', '16 GB', '32 GB'], dtype=object)

# %%
ram_gb ={
    '4 GB':4, '8 GB':8, '16 GB':16, '32 GB':32
}

# %%
df['ram_gb']=df['ram_gb'].map(ram_gb)

# %%
df['ram_type'].unique()
# Out:
# array(['DDR4', 'LPDDR4', 'LPDDR4X', 'DDR5', 'DDR3', 'LPDDR3'],
#       dtype=object)

# %%
ram_type ={
    'DDR4':1, 'LPDDR4':2, 'LPDDR4X':3, 'DDR5':4, 'DDR3':5, 'LPDDR3':6
}

# %%
df['ram_type']=df['ram_type'].map(ram_type)

# %%
df['ssd'].unique()
# Out:
# array(['0 GB', '512 GB', '256 GB', '128 GB', '1024 GB', '2048 GB',
#        '3072 GB'], dtype=object)

# %%
ssd ={
    '0 GB':0, '512 GB':512, '256 GB':256, '128 GB':128, '1024 GB':1024, '2048 GB':2048, '3072 GB':3072
}

# %%
df['ssd']=df['ssd'].map(ssd)

# %%
df['hdd'].unique()
# Out:
# array(['1024 GB', '0 GB', '512 GB', '2048 GB'], dtype=object)

# %%
hdd ={
    '0 GB':0, '512 GB':512, '256 GB':256, '128 GB':128, '1024 GB':1024, '2048 GB':2048, '3072 GB':3072
}

# %%
df['hdd']=df['hdd'].map(hdd)

# %%
df['os'].unique()
# Out:
# array(['Windows', 'DOS', 'Mac'], dtype=object)

# %%
os ={
    'Windows':1, 'DOS':2, 'Mac':3
}

# %%
df['os']=df['os'].map(os)

# %%
df
# Out:
#       brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 0      ASUS                1               1               10       4
# 1    Lenovo                1               1               10       4
# 2    Lenovo                1               1               10       4
# 3      ASUS                1               2               10       8
# 4      ASUS                1               3                0       4
# ..      ...              ...             ...              ...     ...
# 818    ASUS                2              11                0       4
# 819    ASUS                2              11                0       4
# 820    ASUS                2              11                0       4
# 821    ASUS                2              11                0       4
# 822  Lenovo                2               4               10       8
#
#      ram_type   ssd   hdd  os  os_bit graphic_card_gb      weight  \
# ...

# %%
df['os_bit'].unique()
# Out:
# array(['64-bit', '32-bit'], dtype=object)

# %%
os_bit ={
    '64-bit':64, '32-bit':32
}

# %%
df['os_bit']=df['os_bit'].map(os_bit)

# %%
df['graphic_card_gb'].unique()
# Out:
# array(['0 GB', '2 GB', '4 GB', '6 GB', '8 GB'], dtype=object)

# %%
graphic_card_gb ={
    '0 GB':0, '2 GB':2, '4 GB':4, '6 GB':6, '8 GB':8
}

# %%
df['graphic_card_gb']=df['graphic_card_gb'].map(graphic_card_gb)

# %%
df['weight'].unique()
# Out:
# array(['Casual', 'ThinNlight', 'Gaming'], dtype=object)

# %%
weight ={
    'Casual':0, 'ThinNlight':1, 'Gaming':2
}

# %%
df['weight']=df['weight'].map(weight)

# %%
df['warranty'].unique()
# Out:
# array(['No warranty', '1 year', '2 years', '3 years'], dtype=object)

# %%
warranty ={
    'No warranty':0, '1 year':1, '2 years':2, '3 years':3
}

# %%
df['warranty']=df['warranty'].map(warranty)

# %%
df['Touchscreen'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
Touchscreen ={
    'No':0, 'Yes':1
}

# %%
df['Touchscreen']=df['Touchscreen'].map(Touchscreen)

# %%
df['msoffice'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
msoffice ={
    'No':0, 'Yes':1
}
df['msoffice']=df['msoffice'].map(msoffice)

# %%
df['Price'].unique()
# Out:
# array([ 34649,  38999,  39999,  69990,  26990,  22990,  21990,  58799,
#         49999,  59990,  93700,  72990,  17490,  35990,  56490,  65390,
#         31999,  32490,  31799,  29890,  23990,  32955,  46200,  34429,
#         37990,  33980,  39990,  39490,  53990,  38990,  37890,  41990,
#         45990,  42490,  36990,  38940,  42990,  49990,  41490,  38490,
#         44990,  36490,  38970,  44900,  44427,  40200,  40990,  71999,
#         41998,  39998,  48490,  44376,  43900,  46690,  43990,  48500,
#         48990,  23490,  54238,  51990,  43970,  54990,  41250,  60790,
#         45650,  45490,  38799,  69267,  51649,  47990,  44890,  50990,
#         48900,  41790,  57999,  45930,  55490,  32890,  42190,  43690,
#         43800,  34990,  38900,  40890,  39790,  35590,  33990,  43400,
#         24990,  40750,  43000,  38000,  49279,  41500,  36999,  42900,
#         21490,  41480,  32990,  38680,  40390,  20490,  44490,  41890,
# ...

# %%
df
# Out:
#       brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 0      ASUS                1               1               10       4
# 1    Lenovo                1               1               10       4
# 2    Lenovo                1               1               10       4
# 3      ASUS                1               2               10       8
# 4      ASUS                1               3                0       4
# ..      ...              ...             ...              ...     ...
# 818    ASUS                2              11                0       4
# 819    ASUS                2              11                0       4
# 820    ASUS                2              11                0       4
# 821    ASUS                2              11                0       4
# 822  Lenovo                2               4               10       8
#
#      ram_type   ssd   hdd  os  os_bit  graphic_card_gb  weight  warranty  \
# ...

# %%
df['rating'].unique()
# Out:
# array(['2 stars', '3 stars', '4 stars', '5 stars', '1 star'], dtype=object)

# %%
rating ={
    '2 stars':2, '3 stars':3, '4 stars':4, '5 stars':5, '1 star':1
}

# %%
df['rating']=df['rating'].map(rating)

# %%
df
# Out:
#       brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 0      ASUS                1               1               10       4
# 1    Lenovo                1               1               10       4
# 2    Lenovo                1               1               10       4
# 3      ASUS                1               2               10       8
# 4      ASUS                1               3                0       4
# ..      ...              ...             ...              ...     ...
# 818    ASUS                2              11                0       4
# 819    ASUS                2              11                0       4
# 820    ASUS                2              11                0       4
# 821    ASUS                2              11                0       4
# 822  Lenovo                2               4               10       8
#
#      ram_type   ssd   hdd  os  os_bit  graphic_card_gb  weight  warranty  \
# ...

# %%
x = df.drop(['Price', 'brand'], axis=1)
y = df['Price']

# %%
x.duplicated().sum()
# Out:
# np.int64(48)

# %%
#x.drop_duplicates(inplace=True)

# %%
y.duplicated().sum()
# Out:
# np.int64(397)

# %%
#y.drop_duplicates(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 802 entries, 0 to 822
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand              802 non-null    object
#  1   processor_brand    802 non-null    int64
#  2   processor_name     802 non-null    int64
#  3   processor_gnrtn    802 non-null    int64
#  4   ram_gb             802 non-null    int64
#  5   ram_type           802 non-null    int64
#  6   ssd                802 non-null    int64
#  7   hdd                802 non-null    int64
#  8   os                 802 non-null    int64
#  9   os_bit             802 non-null    int64
#  10  graphic_card_gb    802 non-null    int64
#  11  weight             802 non-null    int64
#  12  warranty           802 non-null    int64
#  13  Touchscreen        802 non-null    int64
#  14  msoffice           802 non-null    int64
#  15  Price              802 non-null    int64
# ...

# %%
x
# Out:
#      processor_brand  processor_name  processor_gnrtn  ram_gb  ram_type   ssd  \
# 0                  1               1               10       4         1     0
# 1                  1               1               10       4         1     0
# 2                  1               1               10       4         1     0
# 3                  1               2               10       8         1   512
# 4                  1               3                0       4         1     0
# ..               ...             ...              ...     ...       ...   ...
# 818                2              11                0       4         1  1024
# 819                2              11                0       4         1  1024
# 820                2              11                0       4         1  1024
# 821                2              11                0       4         1  1024
# 822                2               4               10       8         1   512
#
# ...

# %%
y
# Out:
# 0       34649
# 1       38999
# 2       39999
# 3       69990
# 4       26990
#         ...
# 818    135990
# 819    144990
# 820    149990
# 821    142990
# 822     57490
# Name: Price, Length: 802, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)

# %%
x_train, y_train, x_test, y_test = x_train, y_train, x_test, y_test.drop_duplicates()

# %%
x_test
# Out:
#      processor_brand  processor_name  processor_gnrtn  ram_gb  ram_type   ssd  \
# 196                1               2                0       8         4     0
# 299                1               2               11       8         3   512
# 171                1               1               10       8         1   256
# 537                1               5               10      16         1  1024
# 551                1               5               11      16         1  1024
# ..               ...             ...              ...     ...       ...   ...
# 368                1               2               11       8         3   512
# 361                1               2               10       8         1   512
# 446                1               2               11       8         1   256
# 767                2              10                0       4         1   512
# 529                1               5               11      16         1   512
#
# ...

# %%
x_train
# Out:
#      processor_brand  processor_name  processor_gnrtn  ram_gb  ram_type  ssd  \
# 442                1               2               11       8         1  256
# 598                1               5               10      16         3    0
# 452                1               2               11       8         1  256
# 696                2               4                0       8         1  512
# 339                1               2               11       8         3  512
# ..               ...             ...              ...     ...       ...  ...
# 73                 1               1               10       4         1  256
# 108                1               1               11       8         1  512
# 275                1               2               10       8         1  512
# 445                1               2               11       8         1  256
# 104                1               1               11       8         1  512
#
# ...

# %%
y_test
# Out:
# 196     50990
# 299     72990
# 171     41490
# 537    144690
# 551    129990
#         ...
# 258     47990
# 588    139990
# 361    126000
# 767    106990
# 529    110999
# Name: Price, Length: 115, dtype: int64

# %%
y_train
# Out:
# 442     50990
# 598    146490
# 452     60190
# 696     59490
# 339     99990
#         ...
# 73      41990
# 108     60790
# 275     57500
# 445     52990
# 104     44990
# Name: Price, Length: 641, dtype: int64

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
df
# Out:
#       brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 0      ASUS                1               1               10       4
# 1    Lenovo                1               1               10       4
# 2    Lenovo                1               1               10       4
# 3      ASUS                1               2               10       8
# 4      ASUS                1               3                0       4
# ..      ...              ...             ...              ...     ...
# 818    ASUS                2              11                0       4
# 819    ASUS                2              11                0       4
# 820    ASUS                2              11                0       4
# 821    ASUS                2              11                0       4
# 822  Lenovo                2               4               10       8
#
#      ram_type   ssd   hdd  os  os_bit  graphic_card_gb  weight  warranty  \
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
lr.predict(x_test)
# Out:
# array([ 55597.24299192,  79841.81004086,  46475.9035042 , 144867.64170205,
#        162509.18492632, 149040.04193387, 132574.06015663,  93108.5855879 ,
#         59329.02706213,  98097.30524976,  43536.87494213,  37290.77654007,
#         80630.89314474, 102950.72640031,  54854.06572404, 114910.61605364,
#         77682.12766119,  56275.05836906,  65098.20739468, 160229.4342348 ,
#         35630.4270402 ,  38313.08774742,  72884.49054378,  43287.78051055,
#         25994.21310014,  45055.88699747,  77075.06219051, 161341.50224334,
#         44896.63546012,  34696.89842281,  59684.97541485,  57198.62628103,
#         54770.07340627,  62344.22000438,  59427.1170613 ,  28756.19330545,
#        175565.88196044,  81315.3015514 ,  48620.75633993,  63164.35140106,
#         28926.15798081,  69498.59246507,  48725.0164909 ,  45452.48918425,
#        133704.9916303 ,  51116.41922245, 135119.08216657,  63896.67748601,
# ...

# %%
Asus =lr.predict([[	1,	2,	0,	8,	4,	0,	512,	1,	32,	4,	0,	0,	0,	0,	4,	10966,	1185]])
# Out:
# c:\Users\Dell\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
Asus
# Out:
# array([55597.24299192])

# %%
from sklearn.svm import SVR
sv = SVR()

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
lr.predict(x_test)
# Out:
# array([ 55597.24299192,  79841.81004086,  46475.9035042 , 144867.64170205,
#        162509.18492632, 149040.04193387, 132574.06015663,  93108.5855879 ,
#         59329.02706213,  98097.30524976,  43536.87494213,  37290.77654007,
#         80630.89314474, 102950.72640031,  54854.06572404, 114910.61605364,
#         77682.12766119,  56275.05836906,  65098.20739468, 160229.4342348 ,
#         35630.4270402 ,  38313.08774742,  72884.49054378,  43287.78051055,
#         25994.21310014,  45055.88699747,  77075.06219051, 161341.50224334,
#         44896.63546012,  34696.89842281,  59684.97541485,  57198.62628103,
#         54770.07340627,  62344.22000438,  59427.1170613 ,  28756.19330545,
#        175565.88196044,  81315.3015514 ,  48620.75633993,  63164.35140106,
#         28926.15798081,  69498.59246507,  48725.0164909 ,  45452.48918425,
#        133704.9916303 ,  51116.41922245, 135119.08216657,  63896.67748601,
# ...

# %%
sv.fit(x_train, y_train)
# Out:
# SVR()

# %%
pred =sv.predict(x_test)
pred
# Out:
# array([64028.7919338 , 64089.50255335, 63996.70923421, 64119.39478548,
#        64119.44311433, 64119.58053168, 64029.05616895, 64091.44354151,
#        64089.30750509, 64055.6243796 , 64068.49272706, 63979.25185903,
#        64091.54090069, 64119.63566041, 64090.46189989, 64013.10950745,
#        64091.47009768, 64090.4972203 , 64091.44364688, 64119.60704098,
#        63979.12469812, 64068.5215641 , 64091.19168443, 64066.46735922,
#        64018.02722537, 64068.527047  , 64081.27401076, 64119.6515303 ,
#        64067.69154945, 64068.52155596, 63996.19697743, 64090.41297056,
#        63989.67021054, 64091.53306879, 64091.41787153, 64067.5846179 ,
#        64086.89117286, 64091.30955551, 64065.84660834, 64091.10747064,
#        64047.27127282, 64070.68522923, 64090.43933548, 63983.89140293,
#        64090.44248239, 64068.43371696, 64119.45340769, 64091.52614274,
#        64105.64128543, 63996.88239793, 64091.54269732, 64013.29797804,
# ...

# %%
pred[0:100]
# Out:
# array([64028.7919338 , 64089.50255335, 63996.70923421, 64119.39478548,
#        64119.44311433, 64119.58053168, 64029.05616895, 64091.44354151,
#        64089.30750509, 64055.6243796 , 64068.49272706, 63979.25185903,
#        64091.54090069, 64119.63566041, 64090.46189989, 64013.10950745,
#        64091.47009768, 64090.4972203 , 64091.44364688, 64119.60704098,
#        63979.12469812, 64068.5215641 , 64091.19168443, 64066.46735922,
#        64018.02722537, 64068.527047  , 64081.27401076, 64119.6515303 ,
#        64067.69154945, 64068.52155596, 63996.19697743, 64090.41297056,
#        63989.67021054, 64091.53306879, 64091.41787153, 64067.5846179 ,
#        64086.89117286, 64091.30955551, 64065.84660834, 64091.10747064,
#        64047.27127282, 64070.68522923, 64090.43933548, 63983.89140293,
#        64090.44248239, 64068.43371696, 64119.45340769, 64091.52614274,
#        64105.64128543, 63996.88239793, 64091.54269732, 64013.29797804,
# ...

# %%
sv.score(x_train, y_train)
# Out:
# -0.0649275866046346

# %%
lr
# Out:
# LinearRegression()

# %%
print(x_train.shape)
print(y_train.shape)
# Out:
# (641, 17)
# (641,)

# %%
y_train =y_train.values.ravel()

# %%
import imblearn
from imblearn.over_sampling import SMOTE
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[88], line 1
# ----> 1 import imblearn
#       2 from imblearn.over_sampling import SMOTE
#
# ModuleNotFoundError: No module named 'imblearn'

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

#Apply SMOTE to the training data
sm = SMOTE(random_state=42)

# %%
pred =sv.predict(x_test)
pred
# Out:
# array([64028.7919338 , 64089.50255335, 63996.70923421, 64119.39478548,
#        64119.44311433, 64119.58053168, 64029.05616895, 64091.44354151,
#        64089.30750509, 64055.6243796 , 64068.49272706, 63979.25185903,
#        64091.54090069, 64119.63566041, 64090.46189989, 64013.10950745,
#        64091.47009768, 64090.4972203 , 64091.44364688, 64119.60704098,
#        63979.12469812, 64068.5215641 , 64091.19168443, 64066.46735922,
#        64018.02722537, 64068.527047  , 64081.27401076, 64119.6515303 ,
#        64067.69154945, 64068.52155596, 63996.19697743, 64090.41297056,
#        63989.67021054, 64091.53306879, 64091.41787153, 64067.5846179 ,
#        64086.89117286, 64091.30955551, 64065.84660834, 64091.10747064,
#        64047.27127282, 64070.68522923, 64090.43933548, 63983.89140293,
#        64090.44248239, 64068.43371696, 64119.45340769, 64091.52614274,
#        64105.64128543, 63996.88239793, 64091.54269732, 64013.29797804,
# ...

# %%
pred[0:20]
# Out:
# array([64028.7919338 , 64089.50255335, 63996.70923421, 64119.39478548,
#        64119.44311433, 64119.58053168, 64029.05616895, 64091.44354151,
#        64089.30750509, 64055.6243796 , 64068.49272706, 63979.25185903,
#        64091.54090069, 64119.63566041, 64090.46189989, 64013.10950745,
#        64091.47009768, 64090.4972203 , 64091.44364688, 64119.60704098])

# %%
y_test[0:20]
# Out:
# 196     50990
# 299     72990
# 171     41490
# 537    144690
# 551    129990
# 809    142990
# 610    104990
# 328     64990
# 222     51990
# 415    125394
# 68      41990
# 658     32917
# 239     65990
# 819    144990
# 758     57999
# 433    291190
# 316    106490
# 111     45490
# 280     61290
# 544    154990
# Name: Price, dtype: int64

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dtr = DecisionTreeRegressor()
dtr.fit(x_train,y_train)
pred = dtr.predict(x_test)
pred
# Out:
# array([ 52490.        , 105990.        ,  39999.        , 136990.        ,
#        199990.        , 124990.        , 102990.        , 111890.        ,
#         72900.        , 155411.        ,  43900.        ,  39990.        ,
#         79596.        , 127493.33333333,  92990.        , 109990.        ,
#         77990.        ,  38990.        ,  55999.        ,  93955.        ,
#         32955.        ,  35990.        ,  64990.        ,  32490.        ,
#         42490.        ,  48500.        ,  58999.        , 159990.        ,
#         67490.        ,  44427.        ,  58990.        ,  59990.        ,
#         44490.        ,  94000.        ,  80990.        ,  44427.        ,
#        169990.        ,  70990.        ,  54238.        ,  66999.        ,
#         39490.        ,  75990.        ,  49990.        ,  38680.        ,
#        128990.        ,  61990.        ,  62990.        ,  92990.        ,
# ...

# %%
dtr.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'criterion': 'squared_error',
#  'max_depth': None,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'random_state': None,
#  'splitter': 'best'}

# %%
df.to_csv('laptop.csv',index=False)

# %%
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
rfr = RandomForestRegressor()
rfr.fit(x,y)
# Out:
# RandomForestRegressor()

# %%
rfr.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'criterion': 'squared_error',
#  'max_depth': None,
#  'max_features': 1.0,
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
rfr.score(x,y)
# Out:
# 0.9595014092817316

# %%
rfc = RandomForestClassifier(n_estimators=250, criterion="gini", min_samples_split=4, min_samples_leaf=1)
rfc.fit(x, y)
# Out:
# c:\Users\om sai compurer1\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\ensemble\_forest.py:830: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   check_classification_targets(y)
# c:\Users\om sai compurer1\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\tree\_classes.py:297: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   check_classification_targets(y)
# c:\Users\om sai compurer1\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\tree\_classes.py:297: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   check_classification_targets(y)
# ...

# %%
rfc.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'sqrt',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 4,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'n_estimators': 250,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
rfc.score(x,y)
# Out:
# 0.9364089775561097
